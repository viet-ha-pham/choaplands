# %% [markdown]
# # Chuẩn bị từ điển

# %%
import pickle 
with open("vie_cho_dct_2023.pkl","rb") as f:
    vie_cho_dct = pickle.load(f)

# %%
vie_cho_dct
# Out:
# {'và': 'pép',
#  'của': 'ruỷn',
#  'có': 'pỗi',
#  'các': 'nẳm',
#  'là': 'xẫm',
#  'được': 'voẵn',
#  'trong': 'phoãi',
#  'cho': 'đoách',
#  'không': 'gioẵn',
#  'người': 'giớt',
#  'với': 'đưm',
#  'một': 'noen',
#  'đã': 'trõi',
#  'công': 'truỷn',
#  'để': 'nhướng',
#  'những': 'khoáp',
#  'khi': 'muyễn',
#  'đến': 'khiễn',
#  'về': 'đoạo',
#  'này': 'bọm',
#  'tại': 'loăn',
#  'ở': 'phấu',
#  'cũng': 'duýnh',
#  'tôi': 'ìu',
#  'ra': 'giướn',
#  'năm': 'chẫn',
#  'nhiều': 'khềnh',
#  'từ': 'hiễu',
#  'việc': 'sửm',
#  'đồng': 'ruậng',
#  'nhà': 'trõ',
#  'làm': 'phoẻo',
#  'đó': 'thịm',
#  'hiện': 'doòng',
#  'ông': 'dét',
#  'vào': 'trễn',
#  'học': 'siệm',
#  'bị': 'thìu',
#  'trên': 'chuợ',
#  'thể': 'giềnh',
#  'theo': 'voặt',
#  'trường': 'muềnh',
#  'như': 'xạng',
#  'ngày': 'đoắng',
#  'anh': 'giuấng',
#  'đầu': 'vín',
#  'nước': 'duếnh',
#  'phải': 'doảy',
#  'thành': 'guậy',
#  'định': 'pặc',
#  'bộ': 'sựm',
#  'nhân': 'đuỵt',
#  'sẽ': 'khướn',
#  'gia': 'xuồm',
#  'quan': 'ịnh',
#  'sự': 'khuý',
#  'nam': 'trý',
#  'lại': 'loẵng',
#  'chỉ': 'nhề',
#  'số': 'ngốm',
#  'hàng': 'đoáp',
#  'con': 'giền',
#  'sinh': 'vuỳ',
#  'động': 'cuỳu',
#  'sau': 'poảy',
#  'điều': 'sãnh',
#  'chính': 'gượp',
#  'dân': 'nhếm',
#  'cơ': 'ghiếm',
#  'nhưng': 'thộn',
#  'việt': 'quoa',
#  'đi': 'ưỡng',
#  'quốc': 'nuễnh',
#  'thì': 'nhoa',
#  'còn': 'nộc',
#  'biết': 'nhuôi',
#  'hội': 'guôi',
#  'hơn': 'huôn',
#  'thời': 'roẹ',
#  'thông': 'dửa',
#  'an': 'phủm',
#  'trung': 'tưởu',
#  'vụ': 'moánh',
#  'giá': 'gực',
#  'viên': 'thướu',
#  'thực': 'phuồng',
#  'lý': 'tẫu',
#  'phát': 'đy',
#  'nên': 'giụm',
#  'nhận': 'bểu',
#  'hành': 'ngạu',
#  'nhất': 'khoóc',
#  'chủ': 'boàm',
#  'hợp': 'nhoỏng',
#  'rất': 'gúc',
#  'mình': 'khệp',
#  'đang': 'hễn',
#  'qua': 'đuợ',
#  'xe': 'nghíp',
#  'văn': 'qũn',
#  'trước': 'thườu',
#  'do': 'ghĩu',
#  'cao': 'quễn',
#  'mới': 'thoóng',
#  'trình': 'quộp',
#  'cùng': 'ghiệm',
#  'mà': 'độm',
#  'đại': 'nuếnh',
#  'vì': 'oằm',
#  'bạn': 'giỗm',
#  'thế': 'doăng',
#  'thị': 'sươu',
#  'sản': 'sậc',
#  'em': 'thoẹ',
#  'đây': 'día',
#  'tế': 'uỳu',
#  'đường': 'vuỳu',
#  'cả': 'ượp',
#  'đối': 'mảu',
#  'bệnh': 'choỏng',
#  'hai': 'quĩu',
#  'án': 'xoải',
#  'nói': 'vến',
#  'thi': 'khốt',
#  'tiếp': 'phúa',
#  'chức': 'chãy',
#  'tư': 'khổi',
#  'hình': 'gioét',
#  'nghiệp': 'duôm',
#  'nội': 'ngũi',
#  'tình': 'khoõng',
#  'hà': 'nhoành',
#  'nguyễn': 'loen',
#  'tiền': 'xuây',
#  'dự': 'chướm',
#  'lượng': 'nhạm',
#  'lên': 'coẹm',
#  'tin': 'puột',
#  'điểm': 'poãnh',
#  'bình': 'pượi',
#  'cấp': 'choẽn',
#  'báo': 'vốt',
#  'kinh': 'oạnh',
#  'đề': 'nghéc',
#  'tác': 'giặng',
#  'dụng': 'phuở',
#  'bảo': 'vỏm',
#  'xã': 'toén',
#  'tâm': 'giễnh',
#  'xuất': 'nhoát',
#  'tỉnh': 'nhoảy',
#  'cô': 'chựn',
#  'nay': 'lứm',
#  'thanh': 'troài',
#  'bà': 'loắm',
#  'tài': 'phắng',
#  'kết': 'nhuốn',
#  'tuổi': 'gưỡn',
#  'cách': 'hoăn',
#  'vẫn': 'trặng',
#  'thu': 'dướn',
#  'khác': 'dỡm',
#  'đình': 'đưỡm',
#  'cầu': 'guổm',
#  'tăng': 'đễm',
#  'toàn': 'lước',
#  'năng': 'giất',
#  'phương': 'tuệnh',
#  'phòng': 'nhước',
#  'chúng': 'vịu',
#  'thấy': 'moẳm',
#  'tra': 'coạm',
#  'tháng': 'xuốm',
#  'doanh': 'xoèo',
#  'giải': 'guộp',
#  'cần': 'nuộng',
#  'khách': 'suật',
#  'thương': 'quẩng',
#  'tự': 'ngợt',
#  'bản': 'sựi',
#  'thường': 'giuẫy',
#  'chị': 'vuận',
#  'chưa': 'loãm',
#  'ảnh': 'chửn',
#  'ngoài': 'trẳng',
#  'tới': 'pẫng',
#  'sở': 'hứm',
#  'quy': 'dộm',
#  'giao': 'coè',
#  'lớn': 'sẻm',
#  'diễn': 'guyn',
#  'tổ': 'quệp',
#  'ý': 'voải',
#  'yêu': 'nẩng',
#  'liên': 'poét',
#  'lực': 'mết',
#  'pháp': 'xạu',
#  'ăn': 'khọ',
#  'gian': 'giăn',
#  'tập': 'chách',
#  'khu': 'thỗn',
#  'ban': 'puẫy',
#  'cuộc': 'dưu',
#  'sống': 'pọt',
#  'quyết': 'rênh',
#  'phạm': 'xụng',
#  'sĩ': 'khoành',
#  'hoá': 'mãy',
#  'mặt': 'luỷu',
#  'triển': 'gioang',
#  'triệu': 'rựn',
#  'nào': 'chệt',
#  'phần': 'òm',
#  'trẻ': 'choẵm',
#  'hay': 'nừm',
#  'lần': 'phựm',
#  'bằng': 'đuồng',
#  'chất': 'thuớ',
#  'minh': 'quắng',
#  'độ': 'truỳn',
#  'nếu': 'cãn',
#  'trưởng': 'xẹn',
#  'rằng': 'tũi',
#  'giới': 'loặn',
#  'tạo': 'pịt',
#  'quả': 'pặp',
#  'nhiên': 'vuồm',
#  'trọng': 'thuyễn',
#  'vị': 'pữ',
#  'quá': 'vuống',
#  'mẹ': 'nhỉn',
#  'bán': 'nguỵch',
#  'thủ': 'gủ',
#  'trị': 'giệng',
#  'địa': 'voèo',
#  'đưa': 'nuế',
#  'khoảng': 'guần',
#  'họ': 'trem',
#  'đạo': 'muỹ',
#  'tục': 'roằm',
#  'tổng': 'nguỳnh',
#  'tiêu': 'ruých',
#  'ty': 'nưu',
#  'thức': 'vụi',
#  'viện': 'doam',
#  'tham': 'truẫn',
#  'điện': 'quứt',
#  'tính': 'ngoãm',
#  'sử': 'buộng',
#  'mua': 'giữm',
#  'gần': 'nhuỹu',
#  'cảm': 'boọng',
#  'huyện': 'uếch',
#  'hiệu': 'dượi',
#  'phẩm': 'tróp',
#  'cảnh': 'moản',
#  'hệ': 'đuỵu',
#  'bên': 'duổm',
#  'luật': 'moặng',
#  'máy': 'giỡm',
#  'sáng': 'nghểu',
#  'kỳ': 'vợm',
#  'nguyên': 'ợp',
#  'cứu': 'nịp',
#  'vực': 'trựt',
#  'giáo': 'vỡm',
#  'giờ': 'pịu',
#  'mỹ': 'hễu',
#  'hoạt': 'tẹ',
#  'bắt': 'phẽ',
#  'vậy': 'cảy',
#  'kiến': 'vuểnh',
#  'kiểm': 'phoỏng',
#  'đổi': 'nhễn',
#  'xây': 'ghểnh',
#  'đất': 'pẹm',
#  'vừa': 'bờn',
#  'sát': 'troeo',
#  'khó': 'boãm',
#  'nghệ': 'ruầng',
#  'tỷ': 'goác',
#  'trở': 'páy',
#  'gây': 'uýn',
#  'hoàn': 'ngặm',
#  'vấn': 'rìn',
#  'tuy': 'đoào',
#  'đơn': 'ghỳ',
#  'khai': 'giưi',
#  'tốt': 'dõm',
#  'mạnh': 'thoằm',
#  'giảm': 'giứa',
#  'biệt': 'đuờ',
#  'nhiệm': 'iếc',
#  'dựng': 'tửm',
#  'thống': 'vờm',
#  'lúc': 'loẵn',
#  'bất': 'ngoẻn',
#  'trang': 'puỹu',
#  'vi': 'xuôm',
#  'thứ': 'ránh',
#  'rồi': 'nhưm',
#  'phố': 'nhoản',
#  'nghị': 'rẽo',
#  'tiếng': 'kễnh',
#  'đều': 'phuậng',
#  'đặc': 'nhoăn',
#  'chồng': 'phọng',
#  'cáo': 'gẵn',
#  'hồ': 'tẹp',
#  'mức': 'moảy',
#  'chí': 'luê',
#  'chế': 'thuỹn',
#  'xử': 'ngấng',
#  'tượng': 'nguốp',
#  'mỗi': 'vuệ',
#  'nhau': 'nhoẳn',
#  'ta': 'qúng',
#  'gì': 'tuýu',
#  'giúp': 'thạu',
#  'nữ': 'xại',
#  'chuyển': 'khặm',
#  'thêm': 'phột',
#  'đánh': 'gảo',
#  'loại': 'troẻ',
#  'trí': 'phẵm',
#  'tiến': 'soác',
#  'khiến': 'gioằm',
#  'chi': 'địt',
#  'tìm': 'hửi',
#  'muốn': 'duỵnh',
#  'phụ': 'ởm',
#  'cá': 'chòn',
#  'thân': 'nguýn',
#  'chuyện': 'puể',
#  'đoàn': 'ngoẳng',
#  'quyền': 'goắt',
#  'vợ': 'ngoãng',
#  'quản': 'giuần',
#  'đông': 'hâng',
#  'bố': 'poẽm',
#  'chia': 'phoèo',
#  'hoặc': 'gỡm',
#  'sách': 'thuề',
#  'tích': 'mứi',
#  'phim': 'kĩn',
#  'mang': 'coạ',
#  'sức': 'suyệt',
#  'hoa': 'nhêu',
#  'lời': 'thoẹo',
#  'dùng': 'phuyên',
#  'ngân': 'toãy',
#  'chương': 'boẻn',
#  'giám': 'ruyn',
#  'nhập': 'tẽo',
#  'ngành': 'buỹa',
#  'từng': 'phuyền',
#  'nạn': 'trứt',
#  'hết': 'nển',
#  'diện': 'ợi',
#  'chuyên': 'gỡi',
#  'tay': 'mếnh',
#  'tịch': 'xượm',
#  'ngay': 'vưới',
#  'nơi': 'goẽn',
#  'khoa': 'giừi',
#  'dịch': 'ngoảng',
#  'lập': 'quựng',
#  'giữ': 'bồm',
#  'lợi': 'xặc',
#  'chứng': 'goão',
#  'hải': 'thũa',
#  'hộ': 'gượu',
#  'thiết': 'đỉm',
#  'hướng': 'sậng',
#  'phó': 'hựa',
#  'tiên': 'phuỵt',
#  'phục': 'thĩm',
#  'mọi': 'đuểnh',
#  'bao': 'quáp',
#  'xét': 'đoẵm',
#  'dẫn': 'tón',
#  'truyền': 'ruớ',
#  'biểu': 'iềm',
#  'phí': 'soẳng',
#  'ca': 'điệc',
#  'biển': 'quạn',
#  'thư': 'dắng',
#  'bé': 'muỵp',
#  'bỏ': 'lứi',
#  'lịch': 'luẫy',
#  'trần': 'cờm',
#  'chung': 'loéo',
#  'xác': 'chuộm',
#  'vật': 'gioắt',
#  'rõ': 'phoẳng',
#  'giữa': 'xoam',
#  'giả': 'nhâu',
#  'bài': 'xuyển',
#  'sao': 'ngậng',
#  'cái': 'giều',
#  'y': 'oắng',
#  'du': 'nhoãnh',
#  'ứng': 'giuệch',
#  'tử': 'vịp',
#  'đẹp': 'dểnh',
#  'xem': 'phoẽn',
#  'hoàng': 'khửn',
#  'hoà': 'vữ',
#  'dù': 'qúm',
#  'trả': 'gựn',
#  'sẻ': 'cỗng',
#  'chiếc': 'gieng',
#  'đủ': 'thèng',
#  'dài': 'rử',
#  'kiện': 'hộm',
#  'cổ': 'dẹng',
#  'vàng': 'ưởi',
#  'thay': 'pại',
#  'đạt': 'roãy',
#  'thuộc': 'lượi',
#  'kế': 'chuỵt',
#  'gái': 'ẻ',
#  'trợ': 'rở',
#  'lê': 'nghiếu',
#  'ba': 'tẳm',
#  'nhỏ': 'chậng',
#  'ký': 'vỗn',
#  'chọn': 'tuẩn',
#  'chiến': 'phẻn',
#  'câu': 'phĩnh',
#  'thuật': 'coẳn',
#  'sơn': 'nhổi',
#  'mất': 'khoẵng',
#  'hỏi': 'sặng',
#  'gặp': 'vốm',
#  'thái': 'thoạm',
#  'chiều': 'đuỳu',
#  'biến': 'toai',
#  'lấy': 'mỗng',
#  'vệ': 'coáp',
#  'bàn': 'trế',
#  'luôn': 'chạt',
#  'tên': 'goẽo',
#  'phủ': 'oạ',
#  'xảy': 'pày',
#  'danh': 'niều',
#  'quận': 'voáy',
#  'đức': 'xấng',
#  'đúng': 'pẹo',
#  'thích': 'gợp',
#  'dục': 'phoăm',
#  'đảm': 'xuỗng',
#  'bởi': 'xẫu',
#  'ấy': 'hĩa',
#  'tiết': 'niến',
#  'bác': 'nuây',
#  'hạn': 'pót',
#  'hậu': 'gúi',
#  'đời': 'ruềnh',
#  'quân': 'ỵ',
#  'ai': 'giùa',
#  'hưởng': 'bễm',
#  'cây': 'luổi',
#  'quảng': 'troọng',
#  'tranh': 'voam',
#  'so': 'giuyển',
#  'sang': 'thuyn',
#  'đội': 'trượi',
#  'tố': 'oá',
#  'cửa': 'rượn',
#  'vùng': 'nhưỡi',
#  'kể': 'phộ',
#  'nguồn': 'quỹa',
#  'trạng': 'nãnh',
#  'vốn': 'nệp',
#  'nhóm': 'puỹnh',
#  'căn': 'lỉm',
#  'phân': 'mữu',
#  'xuống': 'tuễ',
#  'cuối': 'mịu',
#  'tất': 'ghĩnh',
#  'cứ': 'oàn',
#  'bay': 'trẩm',
#  'nghiệm': 'giạnh',
#  'thí': 'trẫng',
#  'chuẩn': 'rễu',
#  'cố': 'chưu',
#  'tàu': 'puốc',
#  'lao': 'khớm',
#  'mở': 'ĩa',
#  'liệu': 'kịn',
#  'nữa': 'soắt',
#  'tướng': 'giựa',
#  'tối': 'gị',
#  'uỷ': 'phưởu',
#  'lưu': 'boẹ',
#  'đăng': 'thởm',
#  'ít': 'soảnh',
#  'nhạc': 'khười',
#  'mắt': 'cứi',
#  'lãnh': 'luầng',
#  'ngọc': 'trạp',
#  'đoạn': 'gơn',
#  'xin': 'ruỷu',
#  'đốc': 'giưởn',
#  'trực': 'pốp',
#  'đặt': 'pếch',
#  'trách': 'pườu',
#  'bắc': 'phoắc',
#  'tuyển': 'khuộc',
#  'vận': 'xất',
#  'dương': 'xoắt',
#  'riêng': 'giậng',
#  'ngoại': 'nánh',
#  'luận': 'gởm',
#  'mạng': 'khuỗn',
#  'cụ': 'trản',
#  'sơ': 'boãi',
#  'đa': 'buổm',
#  'phía': 'nguốc',
#  'đóng': 'hoam',
#  'tương': 'phuầng',
#  'nông': 'siệng',
#  'yếu': 'vớp',
#  'ninh': 'xướp',
#  'tội': 'cuỷa',
#  'khăn': 'đuỵa',
#  'xuân': 'coám',
#  'mục': 'phuyễn',
#  'nghĩa': 'gioặn',
#  'cạnh': 'gụt',
#  'cháu': 'bửm',
#  'lớp': 'guỹ',
#  'đào': 'khựa',
#  'hoạch': 'giãng',
#  'khẩu': 'giụi',
#  'long': 'suyện',
#  'phong': 'nhửa',
#  'vũ': 'moạm',
#  'phú': 'đoặm',
#  'nghĩ': 'quưỡn',
#  'môi': 'nhướt',
#  'thiếu': 'goáo',
#  'thật': 'giế',
#  'hiểu': 'phuýn',
#  'nổi': 'ghẻm',
#  'chạy': 'troão',
#  'trái': 'lằm',
#  'cán': 'xuềnh',
#  'thuốc': 'tuốm',
#  'kỹ': 'uê',
#  'hữu': 'thỹ',
#  'cục': 'ngọi',
#  'áp': 'sẹng',
#  'cộng': 'quồn',
#  'thuận': 'phuôn',
#  'tinh': 'xiễn',
#  'nhật': 'bâm',
#  'chân': 'xoẳn',
#  'lòng': 'xuỗi',
#  'càng': 'guầy',
#  'dưới': 'chĩ',
#  'nó': 'khưỡu',
#  'nhìn': 'tụn',
#  'đêm': 'xậng',
#  'quang': 'thóm',
#  'nhanh': 'ững',
#  'nghiên': 'troém',
#  'gửi': 'trặm',
#  'hỗ': 'nhấng',
#  'châu': 'đuất',
#  'khá': 'suỗm',
#  'phúc': 'nghiềm',
#  'phép': 'quỏng',
#  'trai': 'duệch',
#  'tải': 'puổng',
#  'đảng': 'đuỷu',
#  'chơi': 'xoẹm',
#  'chết': 'puống',
#  'gọi': 'pủng',
#  'đàn': 'tuốn',
#  'môn': 'nuýu',
#  'tuần': 'dẩm',
#  'lễ': 'pớm',
#  'dung': 'ngăng',
#  'góp': 'nhềnh',
#  'huy': 'poãm',
#  'tân': 'khến',
#  'khả': 'xẳm',
#  'hồi': 'muở',
#  'hôm': 'sươm',
#  'biên': 'đềnh',
#  'lan': 'đoóc',
#  'độc': 'mẫng',
#  'linh': 'giy',
#  'cung': 'cuyu',
#  'toán': 'toãi',
#  'giấy': 'guê',
#  'cường': 'xạnh',
#  'đáng': 'noóc',
#  'tai': 'soặng',
#  'tuyến': 'pượu',
#  'nằm': 'thậu',
#  'gồm': 'quòi',
#  'xúc': 'vớn',
#  'duy': 'rợi',
#  'sắc': 'chuề',
#  'giang': 'phễm',
#  'trao': 'moen',
#  'lo': 'huầy',
#  'bí': 'nễ',
#  'buổi': 'troàn',
#  'thần': 'uề',
#  'sân': 'khững',
#  'đồ': 'phuệ',
#  'thuỷ': 'khươu',
#  'cử': 'luớ',
#  'tây': 'ĩm',
#  'khoẻ': 'tãy',
#  'nghe': 'dườn',
#  'rộng': 'lĩm',
#  'vui': 'phượi',
#  'toà': 'nguốt',
#  'hồng': 'ghịch',
#  'dành': 'nuỗi',
#  'phối': 'roeo',
#  'kim': 'tụp',
#  'khoản': 'oảm',
#  'tấn': 'buấn',
#  'vai': 'troạo',
#  'chống': 'hựng',
#  'lệ': 'vuỹa',
#  'khí': 'giuông',
#  'vô': 'pằm',
#  'lương': 'oỏng',
#  'dễ': 'thĩ',
#  'đầy': 'thoéo',
#  'sư': 'hộn',
#  'nặng': 'nghểnh',
#  'mai': 'cữn',
#  'trò': 'truỵa',
#  'hương': 'dỏi',
#  'nguy': 'phoạc',
#  'hại': 'pườm',
#  'thảo': 'suộn',
#  'đảo': 'phụp',
#  'thiện': 'khoạy',
#  'nuôi': 'truỵp',
#  'ghi': 'phõ',
#  'quán': 'chõn',
#  'chịu': 'phẹn',
#  'tưởng': 'suỵch',
#  'phường': 'gioẳn',
#  'niên': 'oảy',
#  'tết': 'vẫng',
#  'mong': 'rúa',
#  'lộ': 'phuổng',
#  'cực': 'buýn',
#  'vài': 'khữm',
#  'bước': 'quoẹ',
#  'đô': 'soách',
#  'nghiêm': 'goắm',
#  'đà': 'góng',
#  'chấp': 'phoảng',
#  'thuế': 'oãn',
#  'thoại': 'nợp',
#  'đứng': 'niểng',
#  'đôi': 'guỗn',
#  'di': 'võm',
#  'uống': 'choặn',
#  'phản': 'phọn',
#  'nghề': 'phũn',
#  'vọng': 'xếm',
#  'thấp': 'quiệu',
#  'âm': 'qún',
#  'tiện': 'đỗng',
#  'lĩnh': 'uơ',
#  'thẩm': 'dỉu',
#  'dầu': 'gioẽm',
#  'khám': 'noẹm',
#  'màu': 'noách',
#  'hát': 'poóc',
#  'đau': 'moắt',
#  'xa': 'giầng',
#  'hiểm': 'xộp',
#  'lâu': 'quoen',
#  'mô': 'ruyết',
#  'kiếm': 'nỉu',
#  'mặc': 'choèn',
#  'nghỉ': 'luỵnh',
#  'viết': 'giẽng',
#  'phù': 'cuỵp',
#  'nhằm': 'rển',
#  'xuyên': 'dõ',
#  'kỷ': 'vuôm',
#  'ngờ': 'soạo',
#  'yên': 'truể',
#  'mưa': 'lếm',
#  'hạ': 'sữi',
#  'nghi': 'quíu',
#  'kéo': 'bậng',
#  'khởi': 'giuỵt',
#  'ương': 'phẹm',
#  'nâng': 'thiếng',
#  'khẳng': 'giựu',
#  'cư': 'iễm',
#  'mẫu': 'phèm',
#  'trương': 'vuốc',
#  'quý': 'nguổi',
#  'mại': 'duểnh',
#  'phá': 'luỳnh',
#  'chú': 'điệng',
#  'sai': 'pỉu',
#  'ô': 'goặc',
#  'chăm': 'nhữi',
#  'hùng': 'toằn',
#  'suất': 'lướn',
#  'sâu': 'sẩng',
#  'tuấn': 'nhũm',
#  'bức': 'ghiếp',
#  'đọc': 'quiêu',
#  'lâm': 'tuợ',
#  'nợ': 'ngướn',
#  'khỏi': 'quĩn',
#  'phạt': 'qúc',
#  'tín': 'giưỡi',
#  'vượt': 'xuệ',
#  'đấu': 'gỉn',
#  'thiên': 'giưới',
#  'thưởng': 'đữ',
#  'sông': 'nhui',
#  'sớm': 'xểm',
#  'dạy': 'đựm',
#  'cha': 'trếm',
#  'bổ': 'roạo',
#  'cải': 'roẳm',
#  'tuyên': 'nẵn',
#  'chỗ': 'rại',
#  'áo': 'giễng',
#  'hạnh': 'xệnh',
#  'tầng': 'hoãng',
#  'da': 'hẽ',
#  'tạm': 'quòng',
#  'đẩy': 'oày',
#  'dưỡng': 'ngứt',
#  'chữa': 'sước',
#  'vòng': 'óm',
#  'phiên': 'hoách',
#  'đá': 'noác',
#  'mùa': 'bượu',
#  'vay': 'quảu',
#  'hôn': 'rồm',
#  'đâu': 'moáy',
#  'chứ': 'vuếch',
#  'xanh': 'ựu',
#  'quê': 'nhứu',
#  'hút': 'ngườn',
#  'máu': 'gioao',
#  'hiệp': 'khoèm',
#  'nhờ': 'puya',
#  'thăm': 'doỏng',
#  'trú': 'poao',
#  'thuê': 'ghích',
#  'tránh': 'nguý',
#  'khán': 'ngôm',
#  'chẳng': 'dựi',
#  'tiểu': 'phạu',
#  'ánh': 'hứn',
#  'quay': 'mẽo',
#  'soát': 'thuốm',
#  'nhiệt': 'ngẵm',
#  'ngôi': 'dẩng',
#  'thắng': 'giướm',
#  'dũng': 'vuỹn',
#  'món': 'thạy',
#  'thừa': 'chiểng',
#  'ung': 'đuỷn',
#  'cháy': 'cựm',
#  'khắc': 'thuỗm',
#  'ngồi': 'xoao',
#  'phê': 'nèm',
#  'họp': 'buống',
#  'trì': 'roào',
#  'tô': 'hiệc',
#  'quen': 'phặt',
#  'vinh': 'giển',
#  'miền': 'sốn',
#  'chợ': 'toặm',
#  'nhu': 'guẫn',
#  'chắc': 'sể',
#  'nền': 'mỡn',
#  'giống': 'suổn',
#  'nga': 'pôm',
#  'nóng': 'nghịnh',
#  'thôn': 'boạng',
#  'phút': 'quể',
#  'giai': 'nhoạp',
#  'ổn': 'pẽ',
#  'bầu': 'nhoằm',
#  'ưu': 'khụp',
#  'thầy': 'phuỹ',
#  'nhớ': 'mỗm',
#  'mắc': 'gioẽ',
#  'dấu': 'tuỷu',
#  'sóc': 'nuếch',
#  'quanh': 'uộn',
#  'trời': 'phơm',
#  'mối': 'xỏng',
#  'cà': 'hoẵn',
#  'tỉ': 'cuỳ',
#  'thậm': 'xiễng',
#  'chờ': 'giói',
#  'chỉnh': 'xuya',
#  'khánh': 'coẽn',
#  'ma': 'liệc',
#  'thúc': 'xẽn',
#  'lai': 'nhứn',
#  'ngủ': 'tréng',
#  'siêu': 'đăn',
#  'thịt': 'giỷ',
#  'chiếm': 'dẽn',
#  'tức': 'khệch',
#  'đứa': 'đoẵng',
#  'may': 'xuộm',
#  'nẵng': 'díp',
#  'thơ': 'voản',
#  'bày': 'luẩy',
#  'song': 'loạch',
#  'nhiễm': 'miệu',
#  'hãy': 'đẳn',
#  'đón': 'ưỡm',
#  'ấn': 'nhéng',
#  'chuyến': 'xệm',
#  'khảo': 'póng',
#  'phóng': 'quờm',
#  'can': 'trìa',
#  'bánh': 'qùn',
#  'suy': 'siềng',
#  'cân': 'sối',
#  'đáp': 'nuỵt',
#  'vẻ': 'dắp',
#  'khoá': 'poẻo',
#  'lựa': 'pũa',
#  'hưng': 'boẹt',
#  'trải': 'ịp',
#  'truy': 'cuỳn',
#  'lái': 'uểnh',
#  'sợ': 'thoèn',
#  'trồng': 'buếch',
#  'thú': 'mỉnh',
#  'kịp': 'bều',
#  'dòng': 'rễnh',
#  'ích': 'piểm',
#  'lạc': 'truơ',
#  'tỏ': 'khỗng',
#  'hàn': 'moè',
#  'khối': 'viềm',
#  'tặng': 'ghiết',
#  'suốt': 'giũng',
#  'khuyến': 'thiễm',
#  'đổ': 'vứng',
#  'á': 'đoẽn',
#  'đỏ': 'dứm',
#  'phan': 'giệc',
#  'rút': 'voăn',
#  'tái': 'xứn',
#  'mấy': 'hịn',
#  'cũ': 'gõng',
#  'rau': 'puộng',
#  'nghèo': 'gioạt',
#  'mời': 'poáo',
#  'gắn': 'trỉnh',
#  'thụ': 'vạo',
#  'cầm': 'xiện',
#  'tờ': 'pở',
#  'tốc': 'quẩu',
#  'buộc': 'áu',
#  'cam': 'thộc',
#  'ước': 'cũm',
#  'dư': 'toẽo',
#  'biện': 'pới',
#  'quần': 'ngặc',
#  'tim': 'nhởm',
#  'phi': 'quam',
#  'thất': 'nhuổn',
#  'thai': 'quốt',
#  'vong': 'khỗm',
#  'bạc': 'vuýnh',
#  'lãi': 'rãu',
#  'tắc': 'bặn',
#  'the': 'đoác',
#  'khúc': 'suỹnh',
#  'sài': 'gửa',
#  'giác': 'quêu',
#  'ngữ': 'tẫm',
#  'cắt': 'lỉn',
#  'hài': 'cừng',
#  'bè': 'xẫn',
#  'phiếu': 'ngoăm',
#  'niệm': 'hoão',
#  'sửa': 'bượm',
#  'dừng': 'xuýu',
#  'la': 'loách',
#  'thiệt': 'phổn',
#  'xếp': 'phẹt',
#  'tận': 'bược',
#  'tĩnh': 'nguỹnh',
#  'sung': 'quỵn',
#  'thử': 'ngướp',
#  'đài': 'quoả',
#  'thẳng': 'xoém',
#  'to': 'nhuẫn',
#  'dịp': 'kiễu',
#  'thôi': 'nghẽm',
#  'trăm': 'giuynh',
#  'chở': 'quồi',
#  'vĩnh': 'uỵp',
#  'nhẹ': 'muỷ',
#  'sữa': 'thoạp',
#  'nguyện': 'phoẵm',
#  'nêu': 'quẽn',
#  'trắng': 'nghĩm',
#  'sạch': 'poem',
#  'tộc': 'nụm',
#  'cận': 'guỷa',
#  'bóng': 'quề',
#  'chục': 'nừi',
#  'ly': 'ghịu',
#  'dần': 'xoỏng',
#  'phổ': 'quoẽo',
#  'vé': 'rụn',
#  'thác': 'xũa',
#  'sỹ': 'noén',
#  'xong': 'phìu',
#  'lỗi': 'toặng',
#  'chóng': 'tuê',
#  'niềm': 'noòng',
#  'tri': 'thoẳn',
#  'gốc': 'nhớn',
#  'đỡ': 'guốt',
#  'nhi': 'hĩm',
#  'thoát': 'thồm',
#  'chặt': 'tướn',
#  'tù': 'quỉm',
#  'a': 'nhuỷa',
#  'sẵn': 'hượi',
#  'hãng': 'vưởi',
#  'làng': 'soem',
#  'loạt': 'giâu',
#  'gió': 'nhéc',
#  'cười': 'trỗng',
#  'vân': 'boạch',
#  'dạng': 'gioảnh',
#  'gòn': 'trệm',
#  'cưới': 'boát',
#  'vững': 'soao',
#  'lá': 'nù',
#  'dây': 'rướng',
#  'hấp': 'ghiên',
#  'nhắc': 'xỡm',
#  'nộp': 'sượm',
#  'coi': 'phuý',
#  'liệt': 'cưỡn',
#  'nối': 'noặm',
#  'đỗ': 'giuyệt',
#  'kém': 'piệng',
#  'võ': 'gỏ',
#  'luyện': 'puỵch',
#  'lẽ': 'doắc',
#  'sắp': 'tỡi',
#  'bến': 'khóng',
#  'rừng': 'pươm',
#  'nhấn': 'tuẫy',
#  'lạnh': 'xượng',
#  'hầu': 'hỗm',
#  'tôn': 'guốn',
#  'huynh': 'cuyên',
#  'cậu': 'ngứng',
#  'cấu': 'trươn',
#  'chứa': 'thẻm',
#  'cập': 'puềnh',
#  'đám': 'vươm',
#  'xấu': 'xìm',
#  'kiên': 'trày',
#  'gà': 'huộp',
#  'thiệu': 'coem',
#  'lắng': 'voặm',
#  'lạ': 'goã',
#  'lắm': 'hoạy',
#  'sa': 'coành',
#  'lửa': 'ghết',
#  'dao': 'ngưởn',
#  'sắt': 'ngờn',
#  'sóng': 'chộm',
#  'tạp': 'vươu',
#  'đột': 'tráy',
#  'mê': 'tráu',
#  'chụp': 'tuấng',
#  'kê': 'quiệp',
#  'giảng': 'duơ',
#  ...}

# %%
vie_cho_dct_2000 = [ (v,c) for v,c in vie_cho_dct.items()][:2000]

# %%
with open("E:/viechoapdct.txt", "w", encoding="utf-8") as f:
    for a,b in vie_cho_dct_2000:
        f.write(f"{a}\t{b}\n")

# %% [markdown]
# # Các hàm tiện ích

# %%
def trans(txt):
    sp = txt.split()
    return " ".join([ vie_cho_dct[w] if w in vie_cho_dct else w for w in sp]).replace("lồn","noòng").replace("khỏe","tãy")

# %%
def normalize_word(word):
    word = word.replace(".","")
    word = word.replace(",","")
    word = word.replace("?","")
    word = word.replace("!","")
    word = word.replace(":","")
    word = word.replace("(","")
    word = word.replace(")","")
    word = word.replace("\"","")

    return word

# %%
def make_vocab(words):
    l1 = [trans(normalize_word(w)) for w in words]
    l2 = [normalize_word(w) for w in words]
    words = []
    assert len(l1) == len(l2)
    
    for i in range(len(l1)):
        w = f"{l1[i]}: {l2[i]}"
        words.append(w)
    res = "\n".join(list(set(words)))
    res = f"Từ vựng/{trans('từ vựng')}\n\n" + res
    return res

# %%
def beautify(s):
    # viết hoa chữ đầu tiên và chỉnh lại vị trí dấu chấm phẩy v.v...
    res = s[0].upper() + s[1:]
    res = res.replace(" .",".")
    res = res.replace(" ,",",")
    res = res.replace(" ?","?")
    res = res.replace(" !","!")
    res = res.replace(" (","(")
    res = res.replace(" )",")")
    res = res.replace(" \"","\"")
    res = res.replace(" :",":")
    return res

# %%
def normalize_sentence(s):
    # viết thường chữ đầu và chỉnh lại vị trí dấu chấm phẩy v.v...
    res = s[0].lower() + s[1:]
    res = res.replace("."," .")
    res = res.replace(","," ,")
    res = res.replace("?"," ?")
    res = res.replace("!"," !")
    res = res.replace("("," (")
    res = res.replace(")"," )")
    res = res.replace("\""," \"")
    res = res.replace(":"," :")
    return res

# %%
def make_examples(sentences):
    l1 = [ trans(normalize_sentence(s)) for s in sentences ]
    l2 = sentences
    pairs = []
    assert len(l1) == len(l2)
    
    for i in range(len(l1)):
        p = f"{beautify(l1[i])}\n{beautify(l2[i])}"
        pairs.append(p)
    res = "\n\n".join(pairs)
    res = "Ví dụ/Nghỉn nhoảo\n\n" + res
    return res

# %%
def make_unit(title, sentences):
    words = []
    for s in sentences:
        words.extend([ w for w in s.split() if w[0].upper()!=w[0] and w not in ".,?!():\""])
    words = list(set(words))

    return f"""{beautify(title).upper()}/{beautify(trans(title)).upper()}
    
    
{make_vocab(words)}
    
    
{make_examples(sentences)}

#choap
    """

# %%
title = "chúc ngủ ngon"
sentences = [
    "bạn đang làm gì thế ?",
    "tôi vẫn chưa làm xong bài tập .",
    "bạn ngủ đi .",
    "tôi chưa ngủ được .",
    "dạo này có nhiều việc quá .",
    "tôi cảm thấy mình cần cố gắng hơn . ",
    "ừ , đã đến lúc cần thay đổi rồi .",
    "bạn có giỏi toán không ?",
    "tôi không giỏi toán .",
    "bạn có giỏi tiếng Anh không ?",
    "tôi cũng không giỏi tiếng Anh . ",
    "tôi cần tập thể dục nhiều hơn .",
    "mỗi ngày hãy tập thể dục nhé .",
    "cùng nhau tập thể dục nhé .",
     "sẽ ổn thôi .",
    "chúc ngủ ngon ."
]

print(make_unit(title, sentences))
# Out:
# CHÚC NGỦ NGON/ẢU TRÉNG TUỘNG
#
#
# Từ vựng/hiễu puốp
#
# tuýu: gì
# khướn: sẽ
# pỗi: có
# vuống: quá
# đoắng: ngày
# duýnh: cũng
# doăng: thế
# pại: thay
# xuyển: bài
# sửm: việc
# pẽ: ổn
# nhễn: đổi
# phoẻo: làm
# sợn: dạo
# giỗm: bạn
# toãi: toán
# loãm: chưa
# khềnh: nhiều
# nhuộng: giỏi
# phìu: xong
# ảu: chúc
# vuệ: mỗi
# hễn: đang
# bọm: này
# trõi: đã
# nuộng: cần
# nhưm: rồi
# tuộng: ngon
# trặng: vẫn
# chách: tập
# truổn: gắng
# voẵn: được
# moẳm: thấy
# nghẽm: thôi
# niễm: ừ
# chưu: cố
# loẵn: lúc
# gioẵn: không
# khiễn: đến
# đuyết: nhé
# giềnh: thể
# huôn: hơn
# kễnh: tiếng
# boọng: cảm
# nhoẳn: nhau
# đẳn: hãy
# ghiệm: cùng
# ưỡng: đi
# khệp: mình
# ìu: tôi
# tréng: ngủ
# phoăm: dục
#
#
# Ví dụ/Nghỉn nhoảo
#
# Giỗm hễn phoẻo tuýu doăng?
# Bạn đang làm gì thế?
#
# Ìu trặng loãm phoẻo phìu xuyển chách.
# Tôi vẫn chưa làm xong bài tập.
#
# Giỗm tréng ưỡng.
# Bạn ngủ đi.
#
# Ìu loãm tréng voẵn.
# Tôi chưa ngủ được.
#
# Sợn bọm pỗi khềnh sửm vuống.
# Dạo này có nhiều việc quá.
#
# Ìu boọng moẳm khệp nuộng chưu truổn huôn.
# Tôi cảm thấy mình cần cố gắng hơn.
#
# Niễm, trõi khiễn loẵn nuộng pại nhễn nhưm.
# Ừ, đã đến lúc cần thay đổi rồi.
#
# Giỗm pỗi nhuộng toãi gioẵn?
# Bạn có giỏi toán không?
#
# Ìu gioẵn nhuộng toãi.
# Tôi không giỏi toán.
#
# Giỗm pỗi nhuộng kễnh Anh gioẵn?
# Bạn có giỏi tiếng Anh không?
#
# Ìu duýnh gioẵn nhuộng kễnh Anh.
# Tôi cũng không giỏi tiếng Anh.
#
# Ìu nuộng chách giềnh phoăm khềnh huôn.
# Tôi cần tập thể dục nhiều hơn.
#
# Vuệ đoắng đẳn chách giềnh phoăm đuyết.
# Mỗi ngày hãy tập thể dục nhé.
#
# Ghiệm nhoẳn chách giềnh phoăm đuyết.
# Cùng nhau tập thể dục nhé.
#
# Khướn pẽ nghẽm.
# Sẽ ổn thôi.
#
# Ảu tréng tuộng.
# Chúc ngủ ngon.
#
# #choap

# %%
def make_unit_from_txt(file):
    with open(file, "r", encoding="utf-8") as f:
        lines = f.readlines()
    lines = [ beautify(l.strip()) for l in lines if l.strip() ]
    title = normalize_sentence(lines[0])
    sentences = lines[1:]
    words = []
    for s in sentences:
        words.extend([ w for w in s.split() if w[0].upper()!=w[0] and w not in ".,?!():\""])
    words = list(set(words))

    return f"""{beautify(title).upper()}/{beautify(trans(title)).upper()}
    
    
{make_vocab(words)}
    
    
{make_examples(sentences)}

#choap
    """

# %%
import os
import glob

def tim_file_moi_nhat(duong_dan):
    danh_sach_files = glob.glob(os.path.join(duong_dan, '*'))
    if not danh_sach_files:
        return None
    file_moi_nhat = max(danh_sach_files, key=os.path.getctime)
    return file_moi_nhat

# %%
def make_unit_from_folder(path):
    file_moi_nhat = tim_file_moi_nhat(path)
    if file_moi_nhat:
        print(make_unit_from_txt(file_moi_nhat))
    else:
        print("Không tìm thấy file trong thư mục.")

# %% [markdown]
# # Soạn bài học tiếng Choap

# %%
path = "E:/choap"
make_unit_from_folder(path)
# Out:
# TÔI ĐÃ TỪNG ĂN TRƯA Ở NHÀ HÀNG NHẬT BẢN/ÌU TRÕI PHUYỀN KHỌ GIỎNG PHẤU TRÕ ĐOÁP NHẬT BẢN
#
#
# Từ vựng/hiễu puốp
#
# giỏng: trưa
# nhượm: đậu
# gúc: rất
# khọ: ăn
# phấu: ở
# loãm: chưa
# ởm: phụ
# ghẻm: nổi
# trạt: ghét
# đoáp: hàng
# noen: một
# giỷ: thịt
# trõi: đã
# phuyền: từng
# nhưm: rồi
# voẵn: được
# trõ: nhà
# gợp: thích
# gioẵn: không
# cuynh: nướng
# thạy: món
# kễnh: tiếng
# khở: mận
# nhẽm: cay
#
#
# Ví dụ/Nghỉn nhoảo
#
# Ìu trõi phuyền khọ giỏng phấu trõ đoáp Nhật Bản.
# Tôi đã từng ăn trưa ở nhà hàng Nhật Bản.
#
# Giỗm khọ giỏng loãm?
# Bạn ăn trưa chưa?
#
# Ìu loãm khọ.
# Tôi chưa ăn.
#
# Ìu khọ nhưm.
# Tôi ăn rồi.
#
# Ìu trõi phuyền khọ giỏng phấu noen trõ đoáp ghẻm kễnh.
# Tôi đã từng ăn trưa ở một nhà hàng nổi tiếng.
#
# Ìu gúc gợp thạy nhượm ởm Tứ Xuyên.
# Tôi rất thích món đậu phụ Tứ Xuyên.
#
# Ìu gioẵn khọ voẵn thạy nhẽm.
# Tôi không ăn được món cay.
#
# Ìu trạt thạy khọ nhẽm.
# Tôi ghét món ăn cay.
#
# Ìu gợp khọ thạy giỷ cuynh.
# Tôi thích ăn món thịt nướng.
#
# Ìu trõi phuyền gợp khọ khở.
# Tôi đã từng thích ăn mận.
#
# #choap

# %% [markdown]
# # Viết văn bản bí mật bằng tiếng Choap

# %%
status = "Muốn an sẽ an."
beautify(trans(normalize_sentence(status)))
# Out:
# 'Duỵnh phủm khướn phủm.'

# %% [markdown]
# # Viết bài thơ

# %%
import random

def write_poem(keyword1, keyword2, keyword3):
    # Tạo danh sách các câu thơ có thể
    phrases = [
        f"Tôi nhìn {keyword1} và",
        f"Một chiếc {keyword2} đầy {keyword3}",
        f"Biết bao {keyword1} trên đường",
        f"{keyword2} và {keyword3}",
        f"Rung động lòng những {keyword1} kia",
        f"Như những {keyword2} ngọt ngào",
        f"{keyword3} bay lượn trong gió",
        f"Và {keyword1} tràn ngập không gian",
        f"Khi {keyword2} và {keyword3} hòa quyện",
        f"Trong những đêm trăng {keyword1}"]
    
    # Lựa chọn ngẫu nhiên các câu thơ để tạo thành bài thơ
    poem = random.sample(phrases, k=4)
    
    # Trả về bài thơ đã được tạo
    return "\n".join(poem)

# Sử dụng hàm để viết bài thơ
keyword1 = "hoa"
keyword2 = "mây"
keyword3 = "mùa xuân"
poem = write_poem(keyword1, keyword2, keyword3)
print(poem)
# Out:
# mùa xuân bay lượn trong gió
# Tôi nhìn hoa và
# Trong những đêm trăng hoa
# Một chiếc mây đầy mùa xuân

# %%
import random

def write_poem(keywords, num_lines=4):
    phrases = []
    poem = []

    # Tạo danh sách các câu thơ từ các từ khóa
    for keyword in keywords:
        phrases.append(f"{keyword} rực rỡ")
        phrases.append(f"Một {keyword} tuyệt đẹp")
        phrases.append(f"Như {keyword} trong mơ")
        phrases.append(f"Khắp nơi {keyword} tỏa sáng")

    # Lựa chọn ngẫu nhiên các câu thơ
    selected_phrases = random.sample(phrases, num_lines)

    # Xây dựng bài thơ từ các câu thơ đã chọn
    for i in range(num_lines):
        line = selected_phrases[i]
        if i % 2 == 0:
            line += ","
        else:
            line += "."
        poem.append(line)

    # Trả về bài thơ đã được tạo
    return "\n".join(poem)

# Sử dụng hàm để viết bài thơ
keywords = ["hoa", "mây", "mùa xuân", "gió"]
poem = write_poem(keywords, num_lines=6)
print(poem)
# Out:
# Một mây tuyệt đẹp,
# mùa xuân rực rỡ.
# Khắp nơi hoa tỏa sáng,
# Khắp nơi gió tỏa sáng.
# Như gió trong mơ,
# Khắp nơi mùa xuân tỏa sáng.

# %%
def print_triangular_text(text):
    words = text.split()[:28]  # Chỉ lấy 28 từ đầu tiên
    num_words = len(words)
    line_length = 1  # Độ dài của dòng bắt đầu từ 1

    for i in range(num_words):
        print(' '.join(words[:line_length]))
        words = words[line_length:]
        line_length += 1
        if line_length > 7:  # Nếu đạt độ dài dòng là 7, đặt lại độ dài dòng thành 1
            line_length = 1

# Sử dụng hàm với một đoạn văn bản bất kỳ
text = """Trăm năm trong cõi người ta 
Chữ tài chữ mệnh khéo là ghét nhau
Trải qua một cuộc bể dâu
Những điều trông thấy mà đau đớn lòng
"""
print_triangular_text(text)
# Out:
# Trăm
# năm trong
# cõi người ta
# Chữ tài chữ mệnh
# khéo là ghét nhau Trải
# qua một cuộc bể dâu Những
# điều trông thấy mà đau đớn lòng
